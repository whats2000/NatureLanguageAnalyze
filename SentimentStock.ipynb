# %% [markdown]
# # 對ptt股票版「台積電」公司進行情緒分析

# %% [markdown]
# ## 1. 套件說明
# 下面列出在本次實作過程中我們所使用到的相關套件，在這個Jupyter Notebook當中我們將會簡單的展示這些套件的使用方式，關於各個套件的進階使用請同學參照其官網的說明。
# - pandas: 一個資料分析的函式庫，提供了DataFrame等資料格式，與資料處理的函數。
# - matplotlib: 繪圖工具。
# - wordcloud: 繪製文字雲工具。
# - jieba: 中文斷詞工具。

# %% [markdown]
# ## 本機使用套間
# 請先於環境中使用 pip install

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.font_manager as font_manager
from wordcloud import WordCloud 
import jieba

# %% [markdown]
# ## colab 使用套件

# %%
# Path to the custom font
font_path = 'font/TraditionalChinese.ttf'

# Add the custom font to the font manager
font_manager.fontManager.addfont(font_path)

# After adding the font, search for it by filename to get the correct font name
for font in font_manager.fontManager.ttflist:
    if font.fname == font_path:
        print(f"Found font: {font.name}")
        plt.rcParams['font.family'] = font.name
        break
# Out:
# Found font: Noto Sans TC

# %% [markdown]
# ## 2. 資料前處理
# 如 week3 所示
# 使用「吃到飽」作為關鍵字，從工作流程系統中將 ptt 資料下載下來

# %% [markdown]
# ### 2.1 基本資料介紹
# - 資料來源: 工作流程蒐集 PTT 股票版 Stock 2023-03-20 ~ 2024-03-20 所有文章

# %%
df = pd.read_csv("data/raw_data.csv")
df["artDate"] = pd.to_datetime(df["artDate"])
df['artDate'] = df['artDate'].dt.date 
df.head()
# Out:
#    system_id                                             artUrl  \
# 0          1  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 1          2  https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...
# 2          3  https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...
# 3          4  https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...
# 4          5  https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...
#
#                     artTitle     artDate    artPoster artCatagory  \
# 0     [標的]00712富時不動產天天大溢價要賣？  2023-03-20        ATF91       Stock
# 1    [新聞]金融存股勇士進場了！9家金控股東人數創  2023-03-20  black1x2y3z       Stock
# 2            [標的]2753八方雲集鍋貼空  2023-03-20        Timzy       Stock
# 3          [情報]0320上市外資買賣超排行  2023-03-20   saber50116       Stock
# 4  [情報]6667信紘科111年5.11股利4.24  2023-03-20     a0808996       Stock
#
#                                           artContent  \
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1  原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r\n原文連結：\r\nhttps...
# 2  -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 3  1. 標題：外資買賣超排行\r\n\r\n2. 來源：台灣證交所\r\n\r\n3. 網址：...
# 4  https://mops.twse.com.tw/mops/web/t146sb05\r\n...
#
#                                           artComment             e_ip  \
# 0  [{"cmtStatus": "→", "cmtPoster": "hebeisme5566...    42.77.223.199
# 1  [{"cmtStatus": "推", "cmtPoster": "maxdi", "cmt...  140.121.145.184
# 2  [{"cmtStatus": "推", "cmtPoster": "zxcv91039", ...  223.141.185.139
# 3  [{"cmtStatus": "推", "cmtPoster": "powerkshs", ...   111.255.56.173
# 4  [{"cmtStatus": "推", "cmtPoster": "PeaceBoy", "...   123.194.132.40
#
#           insertedDate dataSource
# 0  2023-03-21 02:21:44        ptt
# 1  2023-03-21 02:21:44        ptt
# 2  2023-03-21 02:21:49        ptt
# 3  2023-03-21 02:21:49        ptt
# 4  2023-03-21 02:21:53        ptt

# %% [markdown]
# ### 2.2資料清理

# %%
clear_df = df.copy()

#去除本次不會用到的欄位
drop_cols = ['system_id', 'artPoster', 'artCatagory', 'artComment', 'e_ip', 'insertedDate', 'dataSource']
clear_df.drop(drop_cols, axis = 1, inplace = True)

#去除文章內容為空值的筆數
clear_df.dropna(subset = ['artContent'], axis=0, how='any', inplace=True)

#新增['sentence']欄位，用'。'取代'\n\n'，並移除'\n'
clear_df['sentence'] = clear_df['artContent'].str.replace(r'\n\n','。', regex=True)
clear_df['sentence'] = clear_df['sentence'].str.replace(r'\n','', regex=True)

#移除內文中的網址
clear_df['sentence'] = clear_df['sentence'].replace(r'http\S+', '', regex=True).replace(r'www\S+', '', regex=True)

clear_df
# Out:
#                                                  artUrl  \
# 0     https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 1     https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...
# 2     https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...
# 3     https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...
# 4     https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...
# ...                                                 ...
# 2770  https://www.ptt.cc/bbs/Stock/M.1710843746.A.03...
# 2771  https://www.ptt.cc/bbs/Stock/M.1710851717.A.B6...
# 2772  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 2773  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...
# 2774  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                        artTitle     artDate  \
# 0        [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 1       [新聞]金融存股勇士進場了！9家金控股東人數創  2023-03-20
# 2               [標的]2753八方雲集鍋貼空  2023-03-20
# 3             [情報]0320上市外資買賣超排行  2023-03-20
# 4     [情報]6667信紘科111年5.11股利4.24  2023-03-20
# ...                         ...         ...
# 2770                 [標的]ADM.US  2024-03-19
# 2771     [新聞]賴清德向竹科半導體業掛保證維持兩岸和  2024-03-19
# 2772       [情報]113年03月19日信用交易統計  2024-03-19
# 2773      [情報]0319上市櫃外資投信買超金額排行  2024-03-19
# 2774         [標的]6667信紘科海外擴大營運多  2024-03-19
#
#                                              artContent  \
# 0     1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1     原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r\n原文連結：\r\nhttps...
# 2     -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 3     1. 標題：外資買賣超排行\r\n\r\n2. 來源：台灣證交所\r\n\r\n3. 網址：...
# 4     https://mops.twse.com.tw/mops/web/t146sb05\r\n...
# ...                                                 ...
# 2770  -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 2771  原文標題：\r\n賴清德向竹科半導體業掛保證 維持兩岸和平「水電不用擔心」\r\n\r\n原...
# 2772  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 2773  外資\r\n\r\n排行  股票名稱     百萬   收盤價   漲跌\r\n\r\n1 ...
# 2774  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...
#
#                                                sentence
# 0     1. 標的： 00712 富時不動產\r(例 2330.TW 台積電)\r2. 分類：討論\...
# 1     原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r原文連結：\r\r發布時間：20...
# 2     -\r1.發標的文未充實內文，\r多空理由不充實\r者，板規1-1-5或4-4處份\r2.進...
# 3     1. 標題：外資買賣超排行\r\r2. 來源：台灣證交所\r\r3. 網址：\r\r4. 內...
# 4     \r1.提報董事會或經董事會決議日期:112/03/20\r2.審計委員會通過日期:112/...
# ...                                                 ...
# 2770  -\r1.發標的文未充實內文，\r多空理由不充實\r者，板規1-1-5或4-4處份\r2.進...
# 2771  原文標題：\r賴清德向竹科半導體業掛保證 維持兩岸和平「水電不用擔心」\r\r原文連結：\r...
# 2772  1. 標題：113年03月19日信用交易統計\r2. 來源：臺灣證券交易所、證券櫃檯買賣中心...
# 2773  外資\r\r排行  股票名稱     百萬   收盤價   漲跌\r\r1     2317...
# 2774  1. 標的： 6667 信紘科\r\r2. 分類：多/空/請益/心得\r\r多\r\r3. ...
#
# [2771 rows x 5 columns]

# %% [markdown]
# 斷句

# %%
clear_df['sentence'] = clear_df['sentence'].str.split("[,，。！!？?]{1,}")

sent_df = clear_df.explode('sentence').reset_index(drop=True)

sent_df
# Out:
#                                                   artUrl  \
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 1      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 2      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 3      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 4      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# ...                                                  ...
# 83389  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 83390  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 83391  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 83392  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                      artTitle     artDate  \
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 1      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 2      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 3      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 4      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# ...                       ...         ...
# 83389    [情報]113年03月19日信用交易統計  2024-03-19
# 83390    [情報]113年03月19日信用交易統計  2024-03-19
# 83391    [情報]113年03月19日信用交易統計  2024-03-19
# 83392   [情報]0319上市櫃外資投信買超金額排行  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
#
#                                               artContent  \
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 2      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 3      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 4      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# ...                                                  ...
# 83389  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 83390  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 83391  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 83392  外資\r\n\r\n排行  股票名稱     百萬   收盤價   漲跌\r\n\r\n1 ...
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...
#
#                                                 sentence
# 0      1. 標的： 00712 富時不動產\r(例 2330.TW 台積電)\r2. 分類：討論\...
# 1                                              股價卻沒有急速下跌
# 2                                            是每天凌遲你那種小小跌
# 3                                             明\r天除息0.24
# 4                                           整年殖利率可能有9趴以上
# ...                                                  ...
# 83389  802   張\r券增       9   張\r2404漢唐\r資增     790   ...
# 83390  011   張\r券增     183   張\r=====================...
# 83391                            941   張\r券增     116   張
# 83392  外資\r\r排行  股票名稱     百萬   收盤價   漲跌\r\r1     2317...
# 83393  1. 標的： 6667 信紘科\r\r2. 分類：多/空/請益/心得\r\r多\r\r3. ...
#
# [83394 rows x 5 columns]

# %%
# 初始化斷詞引擎：不一定要設定，只使用內建效果也可以
# 參考網址：https://raw.githubusercontent.com/ldkrsi/jieba-zh_TW/master/jieba/dict.txt

jieba.set_dictionary('dict/dict.txt')
jieba.load_userdict('dict/user_dict.txt')
# Out:
# Building prefix dict from C:\Users\eddie\GitHub\StockNatrakLanguageAnalyze\dict\dict.txt ...
# Loading model from cache C:\Users\eddie\AppData\Local\Temp\jieba.u7ed60b131b91313bb12d624d6950b4ca.cache
# Loading model cost 0.485 seconds.
# Prefix dict has been built successfully.

# %%
#去除句子中除了字母、數字、空白字符以外的符號
sent_df['sentence'] = sent_df['sentence'].str.replace(r'[^\w\s]+|[\d]', '', regex=True).astype(str)

# 把長度小於1的sentence刪掉
sent_df = sent_df[sent_df["sentence"].str.len() > 1]

sent_df
# Out:
#                                                   artUrl  \
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 1      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 2      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 3      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 4      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# ...                                                  ...
# 83389  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 83390  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 83391  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 83392  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                      artTitle     artDate  \
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 1      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 2      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 3      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 4      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# ...                       ...         ...
# 83389    [情報]113年03月19日信用交易統計  2024-03-19
# 83390    [情報]113年03月19日信用交易統計  2024-03-19
# 83391    [情報]113年03月19日信用交易統計  2024-03-19
# 83392   [情報]0319上市櫃外資投信買超金額排行  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
#
#                                               artContent  \
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 2      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 3      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 4      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# ...                                                  ...
# 83389  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 83390  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 83391  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 83392  外資\r\n\r\n排行  股票名稱     百萬   收盤價   漲跌\r\n\r\n1 ...
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...
#
#                                                 sentence
# 0       標的  富時不動產\r例 TW 台積電\r 分類討論\r\r 分析正文\r\r這隻已經超過...
# 1                                              股價卻沒有急速下跌
# 2                                            是每天凌遲你那種小小跌
# 3                                                 明\r天除息
# 4                                            整年殖利率可能有趴以上
# ...                                                  ...
# 83389     張\r券增          張\r漢唐\r資增        張\r券增      ...
# 83390     張\r券增        張\r\r櫃買信用交易統計\r資增       億\r券增 ...
# 83391                                     張\r券增        張
# 83392  外資\r\r排行  股票名稱     百萬   收盤價   漲跌\r\r     鴻海   ...
# 83393   標的  信紘科\r\r 分類多空請益心得\r\r多\r\r 分析正文\r從去年年中看到a大...
#
# [81076 rows x 5 columns]

# %% [markdown]
# ### 2.3 文章斷詞

# %%
word_df = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#去除少於兩個字的詞語
word_df = word_df.loc[word_df['word'].str.len() > 1]

word_df
# Out:
#                                                   artUrl  \
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# ...                                                  ...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                      artTitle     artDate  \
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# ...                       ...         ...
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
#
#                                               artContent     word
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       標的
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       富時
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      不動產
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       TW
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      台積電
# ...                                                  ...      ...
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...     JPTT
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       on
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       my
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...  Samsung
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...      SMS
#
# [472419 rows x 5 columns]

# %% [markdown]
# 移除停用字

# %%
# 以檔案形式匯入通用的停用字檔案
# 將stopwords存成list
stopwords = [line.strip() for line in open('dict/stopwords.txt', 'r', encoding='utf-8').readlines()] 
stopwords_manual = ["原文", "標題", "今年", "來源", "公司", "評論", "署名", "內容時間", "現在", "連結", "目前", "股票",
                    "股價", "台積電", "台積", "台股", "台灣", "台灣股市", "台灣股票", "台灣股價", "台灣股票市場",
                    "台灣股市", "內容", "評論", "文章", "內文", "記者", "指出", "心得", "來源", "市場", "表示", "去年",
                    "預期", "億元", "TW", "持續", "未來", "產業", "券增", "排行", "證券", "今天", "報導", "分類",
                    "網址", "時間", "客戶", "認為", "討論", "張數", "相關", "影響", "機制", "億美元", "美元", "企業",
                    "金額", "資料", "發布", "格式", "投資"]
stopwords.extend(stopwords_manual)

# %%
noStop_df = word_df[~word_df['word'].isin(stopwords)]
noStop_df
# Out:
#                                                   artUrl  \
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 0      https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# ...                                                  ...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
# 83393  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                      artTitle     artDate  \
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# 0      [標的]00712富時不動產天天大溢價要賣？  2023-03-20
# ...                       ...         ...
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
# 83393      [標的]6667信紘科海外擴大營運多  2024-03-19
#
#                                               artContent     word
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       標的
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       富時
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      不動產
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       分析
# 0      1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       正文
# ...                                                  ...      ...
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...     JPTT
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       on
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       my
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...  Samsung
# 83393  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...      SMS
#
# [349902 rows x 5 columns]

# %% [markdown]
# ## 3. Lexicon-based 情緒分析
# 進行基於情緒字典的情緒分析，首先需要準備情緒字典後再將字典與斷詞後的文章進行合併

# %% [markdown]
# ### 3.1 準備LIWC字典
# - 全名Linguistic Inquiry and Word Counts，由心理學家Pennebaker於2001出版
# >  就英文版的LIWC2007來說，目前包含了64個定義類別。這些類別包括基本的語文向度類別，例如： 22個語文特性類別（如，代名詞、冠詞等百分比）、3個副語言學（paralinguistic）類別（如應和詞、停頓詞等）。除了已經有具有明確定義的語文類別之外，LIWC也另外包含了32個心理特性類別（如，情感詞、認知詞等）、7個個人化類別（如工作、休閒活動等）。再加上程式自動計算出的6個一般描述性類別（總詞數、每句詞數等）以及12個標點符號類別（如句點、逗點等），總計可輸出80個字詞類別。
# - https://cliwc.weebly.com/liwc20073542220856.html
# - https://cliwc.weebly.com/35422208563900621029200131228933521259913549826126.html

# %%
# 讀取情緒字典
liwc_dict = pd.read_csv("./dict/liwc/LIWC_CH.csv")
liwc_dict = liwc_dict.rename(columns={'name': 'word', "class": 'sentiments'})
liwc_dict.head()
# Out:
#   word sentiments
# 0   ):     affect
# 1   3q     affect
# 2   :(     affect
# 3   :)     affect
# 4   <3     affect

# %%
liwc_dict['sentiments'].describe()
# Out:
# count       4682
# unique         6
# top       affect
# freq        2061
# Name: sentiments, dtype: object

# %% [markdown]
# ### 3.2 情緒字典與斷詞結果進行合併
# 將情緒字典與斷詞結果進行合併。

# %% [markdown]
# ```merge function 介紹```
# https://www.delftstack.com/zh-tw/howto/python-pandas/merge-dataframes-on-index-in-pandas/

# %%
ptt_liwc_df = pd.merge(noStop_df[["artUrl", "artDate", "artTitle", "artContent", "word"]], liwc_dict, how="left")
ptt_liwc_df
# Out:
#                                                    artUrl     artDate  \
# 0       https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 1       https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 2       https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 3       https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 4       https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# ...                                                   ...         ...
# 365715  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...  2024-03-19
# 365716  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...  2024-03-19
# 365717  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...  2024-03-19
# 365718  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...  2024-03-19
# 365719  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...  2024-03-19
#
#                       artTitle  \
# 0       [標的]00712富時不動產天天大溢價要賣？
# 1       [標的]00712富時不動產天天大溢價要賣？
# 2       [標的]00712富時不動產天天大溢價要賣？
# 3       [標的]00712富時不動產天天大溢價要賣？
# 4       [標的]00712富時不動產天天大溢價要賣？
# ...                        ...
# 365715      [標的]6667信紘科海外擴大營運多
# 365716      [標的]6667信紘科海外擴大營運多
# 365717      [標的]6667信紘科海外擴大營運多
# 365718      [標的]6667信紘科海外擴大營運多
# 365719      [標的]6667信紘科海外擴大營運多
#
#                                                artContent     word sentiments
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       標的        NaN
# 1       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       富時        NaN
# 2       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      不動產        NaN
# 3       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       分析        NaN
# 4       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       正文        NaN
# ...                                                   ...      ...        ...
# 365715  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...     JPTT        NaN
# 365716  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       on        NaN
# 365717  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       my        NaN
# 365718  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...  Samsung        NaN
# 365719  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...      SMS        NaN
#
# [365720 rows x 6 columns]

# %% [markdown]
# ### 3.3 正負向情緒詞彙頻率折線圖圖
# 分別畫出文集中，正向（positive）與負向（negative）情緒的折線圖

# %% [markdown]
# ```情緒分析指標```
# 在情緒分析中，我們會以不同的指標來看情緒的好壞，其中常見的包含：
# 1. **情感詞彙頻率**： 使用情感詞彙列表，其中包含正向和負向情感的詞彙。將文本中的詞與該列表進行匹配，計算正向和負向詞彙的出現次數，從而判斷整體情感傾向。
# 2. **情感詞彙比例**：不同於單純的計算頻率，比例是某種情緒（例如：正向）佔所有情緒詞中的幾分之幾。這種方法可以避免某一天文章數特別多（詞頻也會隨之變多）而影響情緒的判斷。
# 2. **情感詞彙分數**： 給每個情感詞彙分配一個權重或分數，然後計算文本中所有情感詞的總分。這種方法允許區分不同情感詞的影響力，進一步細化情感分析的結果。
#
# 我們先以最基本的詞頻來計算

# %% [markdown]
# ```groupby function 介紹```https://zhuanlan.zhihu.com/p/101284491

# %%
sentiment_count = pd.DataFrame(
    ptt_liwc_df.groupby(["artDate", "sentiments"]).size()
).reset_index()

mask = (sentiment_count['sentiments'] == "positive") | (sentiment_count['sentiments'] == "negative") 
sentiment_count = sentiment_count.loc[mask]

sentiment_count = sentiment_count.rename(columns={0: "size"})
sentiment_count = sentiment_count.sort_values(["artDate"])
sentiment_count
# Out:
#          artDate sentiments  size
# 3     2023-03-20   negative    14
# 4     2023-03-20   positive    12
# 9     2023-03-21   negative    50
# 10    2023-03-21   positive    55
# 15    2023-03-22   negative    23
# ...          ...        ...   ...
# 1714  2024-03-17   positive    14
# 1719  2024-03-18   negative    45
# 1720  2024-03-18   positive    64
# 1725  2024-03-19   negative    19
# 1726  2024-03-19   positive    26
#
# [666 rows x 3 columns]

# %%
colors = ["tab:blue", "tab:orange"]
pos = sentiment_count[sentiment_count["sentiments"] == "positive"]
neg = sentiment_count[sentiment_count["sentiments"] == "negative"]

# fig, ax = plt.subplots(figsize = (6,4), dpi = 150) # 也可以在該圖設定參數
fig, ax = plt.subplots()

ax.plot(pos["artDate"], pos["size"], color=colors[0])
ax.plot(neg["artDate"], neg["size"], color=colors[1])

plt.xlabel("artDate")
# plt.ylabel('size')
ax.legend(["positive", "negative"], loc="upper right")
fig.autofmt_xdate()
plt.title("正負情緒詞彙頻率折線圖")  # 記得加上才能顯示中文
plt.show()

# %% [markdown]
# ```Moving average```
# - rolling average（滾動平均）是一種將時間序列數據平滑化的技術，有助於去除數據中的噪聲，使趨勢更加明顯，同時仍然保留一定的時間特徵。
# - 在情緒分析中，特別是當你有一系列時間序列的情緒數據時，使用滾動平均有助於平滑數據，使情緒趨勢更加清晰。
#     1. **去除瞬間噪聲**： 情緒數據可能受到瞬間事件或噪聲的影響，例如突發的大量評論或新聞。滾動平均有助於平滑這些突變，使你更容易觀察到整體趨勢。
#     2. **強調長期趨勢**： 滾動平均有助於強調長期情緒趨勢，而不受短期波動的干擾。這對於觀察情緒的漸變和長期變化非常有用。

# %%
colors = ["tab:blue", "tab:orange"]
pos = sentiment_count[sentiment_count["sentiments"] == "positive"]
neg = sentiment_count[sentiment_count["sentiments"] == "negative"]

# fig, ax = plt.subplots(figsize = (6,4), dpi = 150) # 也可以在該圖設定參數
fig, ax = plt.subplots()

# 使用 Series.rolling().mean() 來產生 14 天平均
rolling_days = 14
ax.plot(pos["artDate"], pos['size'].rolling(rolling_days).mean(), color=colors[0])
ax.plot(neg["artDate"], neg["size"].rolling(rolling_days).mean(), color=colors[1])

plt.xlabel("artDate")
# plt.ylabel('size')
ax.legend(["positive", "negative"], loc="upper right")
fig.autofmt_xdate()
plt.title("正負情緒聲量折線圖")  # 記得加上才能顯示中文
plt.show()

# %% [markdown]
# 畫出每天的情緒總分數，可以看到正面的詞出現頻率幾乎每天都超過負面，是個氣氛和諧的討論版。

# %% [markdown]
# ```詞頻缺點```
#
# 如果某一天有什麼事件發生而導致正負向詞頻數隨之飆高，在趨勢圖看來可能會認為該區間的正負向情緒較為顯著，但也有可能是因為總體情緒詞彙本來就比較多而導致的。
#
# 以比例的方式來看，我們可以觀察到某個情緒詞在總體情緒詞彙中所佔的比例，就算某一天文章數相較多，也不會影響到比例的呈現。

# %% [markdown]
# ### 3.4 正負向情緒詞彙比例折線圖圖

# %% [markdown]
# ```lambda```函式是一種匿名函式，包含以下幾點特性：
#
# + 不需要定義函式名稱
# + 只能有一行運算式
# + 執行完後會自動回傳結果，不需要return
#
# 因此```lambda```適合在該函式只有單行運算式且不會被重複呼叫時使用
#
# 參考網址：
# [Python Lambda](https://www.w3schools.com/python/python_lambda.asp)
# [Lambda — Python 重要語法技巧](https://medium.com/johnliu-的軟體工程思維/lambda-python-重要語法技巧-27c467ddfa16)

# %%
sentiment_count = sentiment_count.assign(
    ratio=sentiment_count.groupby("artDate")["size"].transform(lambda n: n / n.sum())
)
sentiment_count
# Out:
#          artDate sentiments  size     ratio
# 3     2023-03-20   negative    14  0.538462
# 4     2023-03-20   positive    12  0.461538
# 9     2023-03-21   negative    50  0.476190
# 10    2023-03-21   positive    55  0.523810
# 15    2023-03-22   negative    23  0.273810
# ...          ...        ...   ...       ...
# 1714  2024-03-17   positive    14  0.875000
# 1719  2024-03-18   negative    45  0.412844
# 1720  2024-03-18   positive    64  0.587156
# 1725  2024-03-19   negative    19  0.422222
# 1726  2024-03-19   positive    26  0.577778
#
# [666 rows x 4 columns]

# %%
pos = sentiment_count[sentiment_count["sentiments"] == "positive"]
neg = sentiment_count[sentiment_count["sentiments"] == "negative"]

# %%
fig, ax = plt.subplots()

rolling_days = 14
ax.plot(pos["artDate"], pos["ratio"].rolling(rolling_days).mean(), color=colors[0])
ax.plot(neg["artDate"], neg["ratio"].rolling(rolling_days).mean(), color=colors[1])

plt.xlabel("artDate")
plt.ylabel("ratio")
ax.legend(["positive", "negative"], loc="lower left")
fig.autofmt_xdate()
plt.title("正負情緒比例折線圖")
# Out:
# Text(0.5, 1.0, '正負情緒比例折線圖')

# %% [markdown]
# ### 3.5 正負向情緒分數折線圖

# %%
sentiment_count
# Out:
#          artDate sentiments  size     ratio
# 3     2023-03-20   negative    14  0.538462
# 4     2023-03-20   positive    12  0.461538
# 9     2023-03-21   negative    50  0.476190
# 10    2023-03-21   positive    55  0.523810
# 15    2023-03-22   negative    23  0.273810
# ...          ...        ...   ...       ...
# 1714  2024-03-17   positive    14  0.875000
# 1719  2024-03-18   negative    45  0.412844
# 1720  2024-03-18   positive    64  0.587156
# 1725  2024-03-19   negative    19  0.422222
# 1726  2024-03-19   positive    26  0.577778
#
# [666 rows x 4 columns]

# %%
ptt_sentiment_value = (
    sentiment_count.pivot_table(
        index="artDate", columns="sentiments", values="size", fill_value=0
    )
    .reset_index()
    .rename_axis(None, axis=1)
)
ptt_sentiment_value.head()
# Out:
#       artDate  negative  positive
# 0  2023-03-20      14.0      12.0
# 1  2023-03-21      50.0      55.0
# 2  2023-03-22      23.0      61.0
# 3  2023-03-23      22.0      32.0
# 4  2023-03-24      32.0      26.0

# %%
# sentiment 計算方式: positive - negative
ptt_sentiment_value["sentiment_value"] = (
    ptt_sentiment_value["positive"]
    - ptt_sentiment_value["negative"]
)
ptt_sentiment_value.head()
# Out:
#       artDate  negative  positive  sentiment_value
# 0  2023-03-20      14.0      12.0             -2.0
# 1  2023-03-21      50.0      55.0              5.0
# 2  2023-03-22      23.0      61.0             38.0
# 3  2023-03-23      22.0      32.0             10.0
# 4  2023-03-24      32.0      26.0             -6.0

# %%
fig, ax = plt.subplots()

rolling_days = 14
ax.plot(ptt_sentiment_value["artDate"], ptt_sentiment_value["sentiment_value"].rolling(rolling_days).mean())
ax.set_xlabel("artDate")
ax.set_ylabel("sentiment value")
fig.autofmt_xdate()
plt.title("正負情緒分數趨勢折線圖")
# Out:
# Text(0.5, 1.0, '正負情緒分數趨勢折線圖')

# %% [markdown]
# ### 3.6 文章為單位的情緒分析

# %%
sentiment_count_by_article = pd.DataFrame(
    ptt_liwc_df.groupby(["artUrl", "sentiments"]).size()
).reset_index()
sentiment_count_by_article = sentiment_count_by_article.rename(columns={0: "size"})
sentiment_count_by_article
# Out:
#                                                  artUrl sentiments  size
# 0     https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...     affect     2
# 1     https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...   negative     1
# 2     https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...   positive     1
# 3     https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...     affect     5
# 4     https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...   negative     1
# ...                                                 ...        ...   ...
# 6970  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...     affect     1
# 6971  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...   positive     1
# 6972  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...     affect     5
# 6973  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...   negative     1
# 6974  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...   positive     4
#
# [6975 rows x 3 columns]

# %%
ptt_sentiment_value_by_article = (
    sentiment_count_by_article.pivot_table(
        index="artUrl", columns="sentiments", values="size", fill_value=0
    )
    .reset_index()
    .rename_axis(None, axis=1)
)
ptt_sentiment_value_by_article.head()
# Out:
#                                               artUrl  affect  anger  anx  \
# 0  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...     2.0    0.0  0.0
# 1  https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...     5.0    0.0  0.0
# 2  https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...     4.0    1.0  0.0
# 3  https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...     1.0    0.0  0.0
# 4  https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...     4.0    2.0  0.0
#
#    negative  positive  sad
# 0       1.0       1.0  0.0
# 1       1.0       4.0  1.0
# 2       2.0       2.0  0.0
# 3       0.0       1.0  0.0
# 4       3.0       0.0  2.0

# %%
# sentiment 計算方式: positive - negative
ptt_sentiment_value_by_article["sentiment_value"] = (
    ptt_sentiment_value_by_article["positive"]
    - ptt_sentiment_value_by_article["negative"]
)
ptt_sentiment_value_by_article.head()
# Out:
#                                               artUrl  affect  anger  anx  \
# 0  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...     2.0    0.0  0.0
# 1  https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...     5.0    0.0  0.0
# 2  https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...     4.0    1.0  0.0
# 3  https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...     1.0    0.0  0.0
# 4  https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...     4.0    2.0  0.0
#
#    negative  positive  sad  sentiment_value
# 0       1.0       1.0  0.0              0.0
# 1       1.0       4.0  1.0              3.0
# 2       2.0       2.0  0.0              0.0
# 3       0.0       1.0  0.0              1.0
# 4       3.0       0.0  2.0             -3.0

# %%
ptt_sentiment_value_by_article['sentiment_class'] = ptt_sentiment_value_by_article['sentiment_value'].apply(lambda x: "正向" if x > 0 else "負向" )
ptt_sentiment_value_by_article
# Out:
#                                                  artUrl  affect  anger  anx  \
# 0     https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...     2.0    0.0  0.0
# 1     https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...     5.0    0.0  0.0
# 2     https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...     4.0    1.0  0.0
# 3     https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...     1.0    0.0  0.0
# 4     https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...     4.0    2.0  0.0
# ...                                                 ...     ...    ...  ...
# 2150  https://www.ptt.cc/bbs/Stock/M.1710830890.A.CE...    12.0    3.0  3.0
# 2151  https://www.ptt.cc/bbs/Stock/M.1710843746.A.03...     2.0    0.0  0.0
# 2152  https://www.ptt.cc/bbs/Stock/M.1710851717.A.B6...    26.0    0.0  3.0
# 2153  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...     1.0    0.0  0.0
# 2154  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...     5.0    0.0  0.0
#
#       negative  positive  sad  sentiment_value sentiment_class
# 0          1.0       1.0  0.0              0.0              負向
# 1          1.0       4.0  1.0              3.0              正向
# 2          2.0       2.0  0.0              0.0              負向
# 3          0.0       1.0  0.0              1.0              正向
# 4          3.0       0.0  2.0             -3.0              負向
# ...        ...       ...  ...              ...             ...
# 2150      10.0       2.0  0.0             -8.0              負向
# 2151       1.0       0.0  0.0             -1.0              負向
# 2152       7.0      19.0  0.0             12.0              正向
# 2153       0.0       1.0  0.0              1.0              正向
# 2154       1.0       4.0  0.0              3.0              正向
#
# [2155 rows x 9 columns]

# %%
clear_df_sentiment = pd.merge(df, ptt_sentiment_value_by_article[['artUrl', 'sentiment_class']], how="left")
clear_df_sentiment["artDate"] = pd.to_datetime(clear_df_sentiment["artDate"])
clear_df_sentiment['artDate'] = clear_df_sentiment['artDate'].dt.date
clear_df_sentiment
# Out:
#       system_id                                             artUrl  \
# 0             1  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 1             2  https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...
# 2             3  https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...
# 3             4  https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...
# 4             5  https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...
# ...         ...                                                ...
# 2770       2771  https://www.ptt.cc/bbs/Stock/M.1710843746.A.03...
# 2771       2772  https://www.ptt.cc/bbs/Stock/M.1710851717.A.B6...
# 2772       2773  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 2773       2774  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...
# 2774       2775  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                        artTitle     artDate    artPoster artCatagory  \
# 0        [標的]00712富時不動產天天大溢價要賣？  2023-03-20        ATF91       Stock
# 1       [新聞]金融存股勇士進場了！9家金控股東人數創  2023-03-20  black1x2y3z       Stock
# 2               [標的]2753八方雲集鍋貼空  2023-03-20        Timzy       Stock
# 3             [情報]0320上市外資買賣超排行  2023-03-20   saber50116       Stock
# 4     [情報]6667信紘科111年5.11股利4.24  2023-03-20     a0808996       Stock
# ...                         ...         ...          ...         ...
# 2770                 [標的]ADM.US  2024-03-19     yamakazi       Stock
# 2771     [新聞]賴清德向竹科半導體業掛保證維持兩岸和  2024-03-19      humbler       Stock
# 2772       [情報]113年03月19日信用交易統計  2024-03-19   steward135       Stock
# 2773      [情報]0319上市櫃外資投信買超金額排行  2024-03-19  steveisaman       Stock
# 2774         [標的]6667信紘科海外擴大營運多  2024-03-19      wangggg       Stock
#
#                                              artContent  \
# 0     1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1     原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r\n原文連結：\r\nhttps...
# 2     -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 3     1. 標題：外資買賣超排行\r\n\r\n2. 來源：台灣證交所\r\n\r\n3. 網址：...
# 4     https://mops.twse.com.tw/mops/web/t146sb05\r\n...
# ...                                                 ...
# 2770  -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 2771  原文標題：\r\n賴清德向竹科半導體業掛保證 維持兩岸和平「水電不用擔心」\r\n\r\n原...
# 2772  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 2773  外資\r\n\r\n排行  股票名稱     百萬   收盤價   漲跌\r\n\r\n1 ...
# 2774  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...
#
#                                              artComment             e_ip  \
# 0     [{"cmtStatus": "→", "cmtPoster": "hebeisme5566...    42.77.223.199
# 1     [{"cmtStatus": "推", "cmtPoster": "maxdi", "cmt...  140.121.145.184
# 2     [{"cmtStatus": "推", "cmtPoster": "zxcv91039", ...  223.141.185.139
# 3     [{"cmtStatus": "推", "cmtPoster": "powerkshs", ...   111.255.56.173
# 4     [{"cmtStatus": "推", "cmtPoster": "PeaceBoy", "...   123.194.132.40
# ...                                                 ...              ...
# 2770  [{"cmtStatus": "推", "cmtPoster": "gs13010", "c...     1.200.104.88
# 2771  [{"cmtStatus": "推", "cmtPoster": "nvlsvee", "c...  111.251.205.175
# 2772  [{"cmtStatus": "推", "cmtPoster": "hong92", "cm...    36.224.121.61
# 2773  [{"cmtStatus": "推", "cmtPoster": "fernmmm", "c...     36.234.75.22
# 2774  [{"cmtStatus": "推", "cmtPoster": "tgm0952", "c...     39.15.48.172
#
#              insertedDate dataSource sentiment_class
# 0     2023-03-21 02:21:44        ptt              負向
# 1     2023-03-21 02:21:44        ptt              正向
# 2     2023-03-21 02:21:49        ptt              負向
# 3     2023-03-21 02:21:49        ptt              正向
# 4     2023-03-21 02:21:53        ptt              負向
# ...                   ...        ...             ...
# 2770  2024-03-20 02:05:23        ptt              負向
# 2771  2024-03-20 02:05:27        ptt              正向
# 2772  2024-03-20 02:05:31        ptt             NaN
# 2773  2024-03-20 02:05:31        ptt              正向
# 2774  2024-03-20 02:05:31        ptt              正向
#
# [2775 rows x 12 columns]

# %%
sentiment_art_count = pd.DataFrame(
    clear_df_sentiment.groupby(["artDate", "sentiment_class"]).size()
).reset_index()
sentiment_art_count = sentiment_art_count.rename(columns={0: "size"})
sentiment_art_count = sentiment_art_count.sort_values(["artDate"])
sentiment_art_count
# Out:
#         artDate sentiment_class  size
# 0    2023-03-20              正向     3
# 1    2023-03-20              負向     6
# 2    2023-03-21              正向    11
# 3    2023-03-21              負向     3
# 4    2023-03-22              正向    10
# ..          ...             ...   ...
# 607  2024-03-17              負向     2
# 608  2024-03-18              正向    10
# 609  2024-03-18              負向     7
# 610  2024-03-19              正向     3
# 611  2024-03-19              負向     2
#
# [612 rows x 3 columns]

# %%
colors = ["tab:blue", "tab:orange"]
pos = sentiment_art_count[sentiment_art_count["sentiment_class"] == "正向"]
neg = sentiment_art_count[sentiment_art_count["sentiment_class"] == "負向"]

# fig, ax = plt.subplots(figsize = (6,4), dpi = 150) # 也可以在該圖設定參數
fig, ax = plt.subplots()

# 使用 Series.rolling().mean() 來產生 14 天平均
rolling_days = 14
ax.plot(pos["artDate"], pos['size'].rolling(rolling_days).mean(), color=colors[0])
ax.plot(neg["artDate"], neg["size"].rolling(rolling_days).mean(), color=colors[1])
# ax.plot(pos["artDate"], pos['size'], color=colors[0])
# ax.plot(neg["artDate"], neg["size"], color=colors[1])

plt.xlabel("artDate")
# plt.ylabel('size')
ax.legend(["positive", "negative"], loc="upper right")
fig.autofmt_xdate()
plt.title("正負文章數趨勢折線圖")  # 記得加上才能顯示中文
plt.show()

# %% [markdown]
# 大部分文章都被歸類在正向文章，美食版討論內容大多偏正面

# %% [markdown]
# ### 3.7 情緒代表字

# %%
word_count = ptt_liwc_df.groupby(["word", "sentiments"]).size().reset_index()
word_count = word_count.rename(columns={0: "size"})
word_count = word_count.sort_values(["size"], ascending=False)
word_count
# Out:
#      word sentiments  size
# 379    問題   negative   562
# 378    問題     affect   562
# 985    智慧   positive   384
# 984    智慧     affect   384
# 1701   重要     affect   334
# ...   ...        ...   ...
# 335    可口     affect     1
# 1440   美化   positive     1
# 1439   美化     affect     1
# 1099   氣餒     affect     1
# 1352   確信   positive     1
#
# [1837 rows x 3 columns]

# %%
word_of_pos = word_count.loc[(word_count["sentiments"] == "positive")]
word_of_pos.head(15)
# Out:
#      word sentiments  size
# 985    智慧   positive   384
# 1702   重要   positive   334
# 327    受惠   positive   236
# 601    希望   positive   235
# 1594   謝謝   positive   206
# 987    智能   positive   192
# 671    復甦   positive   177
# 180    優勢   positive   175
# 889    挑戰   positive   171
# 861    投入   positive   169
# 637    強勁   positive   161
# 1372   積極   positive   160
# 937    支持   positive   153
# 1555   解決   positive   149
# 184    優於   positive   149

# %%
word_of_neg = word_count.loc[(word_count["sentiments"] == "negative")]
word_of_neg.head(15)
# Out:
#      word sentiments  size
# 379    問題   negative   562
# 1769   風險   negative   295
# 1549   衰退   negative   158
# 453    壓力   negative   142
# 1726   降低   negative   136
# 1538   虧損   negative   124
# 929    擔心   negative   116
# 1542   衝擊   negative    83
# 820    戰爭   negative    76
# 1229   爆發   negative    66
# 49     不足   negative    64
# 1420   緊張   negative    63
# 912    損失   negative    60
# 905    控制   negative    54
# 932    擔憂   negative    51

# %%
pos = word_of_pos.head(15).sort_values(["size"], ascending=True)
neg = word_of_neg.head(15).sort_values(["size"], ascending=True)

fig, ax = plt.subplots(1, 2)

ax[0].barh(pos["word"], pos["size"], color=colors[0])
ax[0].set_xlabel("count")
ax[0].set_yticklabels(pos["word"])
ax[0].set_title("正向情緒總數")

ax[1].barh(neg["word"], neg["size"], color=colors[1])
ax[1].set_xlabel("count")
ax[1].set_yticklabels(neg["word"])
ax[1].set_title("負向情緒總數")
# Out:
# C:\Users\eddie\AppData\Local\Temp\ipykernel_13276\1734313141.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_yticklabels(pos["word"])
# C:\Users\eddie\AppData\Local\Temp\ipykernel_13276\1734313141.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_yticklabels(neg["word"])
# Text(0.5, 1.0, '負向情緒總數')

# %% [markdown]
# #### 檢查情緒詞是否符合本文本

# %%
filtered_df = sent_df[sent_df['sentence'].str.contains('挑戰', na=False)]
filtered_df.head()
# Out:
#                                                  artUrl  \
# 1782  https://www.ptt.cc/bbs/Stock/M.1679583369.A.63...
# 1784  https://www.ptt.cc/bbs/Stock/M.1679583369.A.63...
# 2310  https://www.ptt.cc/bbs/Stock/M.1679740588.A.7A...
# 3954  https://www.ptt.cc/bbs/Stock/M.1680495138.A.EE...
# 4763  https://www.ptt.cc/bbs/Stock/M.1680912397.A.93...
#
#                      artTitle     artDate  \
# 1782         [標的]Nasdaq強襲魔女集結  2023-03-23
# 1784         [標的]Nasdaq強襲魔女集結  2023-03-23
# 2310  [新聞]華為：完成14奈米以上EDA工具國產化  2023-03-25
# 3954       [新聞]英特爾新世代GPU台積電全吃  2023-04-03
# 4763     [新聞]一週熱門零股國泰永續高股息最搶手  2023-04-08
#
#                                              artContent  \
# 1782  1. 標的：  美股 Nasdaq\r\n(例 2330.TW 台積電)\r\n2. 分類：...
# 1784  1. 標的：  美股 Nasdaq\r\n(例 2330.TW 台積電)\r\n2. 分類：...
# 2310  美斷供「晶片之母」後突圍！華為：完成 14 奈米以上 EDA 工具國產化\r\nhttps:...
# 3954  原文標題：\r\n英特爾新世代GPU 台積電全吃\r\n\r\n原文連結：\r\nhttps...
# 4763  原文標題：一周熱門零股／國泰永續高股息 最搶手\r\n\r\n原文連結：\r\nhttps:...
#
#                                              sentence
# 1782  所以同時間納指應該會挑戰\r但我個人傾向在月中以前必定要完成上述這個過程\r之後納指一定要死守
# 1784                  這樣七月前納指才能挑戰小納挑戰\r\r如果整體量能不想這樣發展
# 2310                                         但仍面臨艱巨挑戰
# 3954                                         營運面臨較大挑戰
# 4763                                    短線仍\r有挑戰萬六的機會

# %%
for sentence in filtered_df['sentence'].to_list():
    print(sentence)
    print("=========================")
# Out:
# 之後納指一定要死守以前必定要完成上述這個過程
# =========================
# 如果整體量能不想這樣發展納挑戰
# =========================
# 但仍面臨艱巨挑戰
# =========================
# 營運面臨較大挑戰
# =========================
# 有挑戰萬六的機會
# =========================
# 供應鏈傳出濟日報 記者李珣瑛挑戰
# =========================
# 成本與人才將是兩項艱鉅的挑戰
# =========================
# 震盪趨堅挑戰萬六關卡
# =========================
# 不以挑戰萬六關卡為滿足
# =========================
# 顯示對台股向上挑戰萬七有一定信心
# =========================
# 讓系統單晶片SoC在功耗性能和可靠性上能應對日益增加的設計挑戰
# =========================
# 亞利桑那州廠儘管執照取得上存在一些挑戰
# =========================
#   現在台積電絕對不貴付未來中美晶片戰爭的危機與海外擴廠可能遇到的未知挑戰
# =========================
# 挑戰萬六以上機率仍高
# =========================
# 片的挑戰性比生產裝置還高
# =========================
# 屢屢挑戰萬六大關失敗
# =========================
# 台股挑戰萬六數度碰壁
# =========================
# 進行了一些討論的一些挑戰
# =========================
# 並面臨建立可持續商業模式的挑戰
# =========================
# 但五大商社業務都得要看大宗商品的臉色
# =========================
# 看好台股有機會挑戰
# =========================
# 台股有機會向上挑戰
# =========================
# 台積電在量產奈米晶片過程中有不少挑戰
# =========================
# 同時年全年對於半導體業者來說則是具有挑戰的一年
# =========================
# 不但帶領台積電大漲挑戰前高
# =========================
# 挑戰四百成功
# =========================
# NVIDIA大漲不僅帶動台積電挑戰前高
# =========================
# 股價皆挑戰波段新高
# =========================
# 成為引領台股挑戰萬七
# =========================
# 的價位站穩應該能挑戰去年
# =========================
# 日股挑戰高點反映兩大重點
# =========================
# 台積電過去幾年經歷許多挑戰
# =========================
# 台積電過去幾年經歷不少挑戰
# =========================
# 台積電在過去幾年經歷許多挑戰
# =========================
# 台積電經歷過去許多的挑戰
# =========================
# 氣候變遷等許多挑戰歷美中貿易戰疫情烏俄戰爭
# =========================
# 不僅在消費級產品有挑戰英特爾之勢
# =========================
# 準備再次挑戰NVIDIA
# =========================
# 隨著超微AI大會登場並蓄勢挑戰輝達
# =========================
# 有望挑戰賺贏去年一整年的表現
# =========================
# 今年營收獲利挑戰歷史巔峰
# =========================
#  年對晶圓代工廠是非常挑戰的一年
# =========================
# 支平衡對公司來說也是一個很大的挑戰
# =========================
# 期間橫跨年的網路時代年智慧型手機時代
# =========================
# 淨零轉型是商機也是挑戰
# =========================
# 至於市場的二大風險為進入除息旺季點數蒸發財報公告形成挑戰
# =========================
# 年來佔據晶圓代工市場主導地位的台積電和三星
# =========================
# 挑戰電和三星可能會面臨重大
# =========================
# 也凸顯台積電海外擴張面臨的挑戰
# =========================
# 不僅突顯台積電海外擴張面臨的挑戰
# =========================
# 在陌生的環境與外國建築工人溝通具有挑戰性
# =========================
# 帶來的挑戰特爾進軍代工市場所
# =========================
# 台積電盛夏挑戰元大關
# =========================
# 全年營收有機會挑戰億元
# =========================
# 幾乎是爆炸性成長營收要高達億
# =========================
# 在技術上面臨挑戰
# =========================
# 逢台股飆漲攻上萬七挑戰萬八大關
# =========================
# 在技術上具挑戰性
# =========================
# 臨挑戰因是在於美國和印度之間劃分和協調工作面
# =========================
# 非長期投資者之前的xxx張還少 只有xxx張
# =========================
# 第三次挑戰該上了吧
# =========================
# 會挑戰有機
# =========================
# 而如果升息一碼給你挑戰那斯達克指數生更大的上爬力道
# =========================
# 尤其無論怎樣率影響很大反觀旁邊的道瓊恩
# =========================
# 法說直說美國廠遇到挑戰
# =========================
# 美國亞利桑那廠區面臨一些挑戰
# =========================
# 面臨終端需求總經環境低迷的挑戰
# =========================
# 原訂下半年逐季成長目標備受挑戰
# =========================
# 事業成本上升在內的通貨膨脹等挑戰影響
# =========================
# 預估年底產能將挑戰萬片以上
# =========================
# 中醒來從挑戰元大關美夢
# =========================
# 註前述兩個稅前eps千位千元以下皆帶零計算
# =========================
# 非長期投資者會再繼續挑戰前高也是意思
# =========================
# 受缺乏熟練安裝設備的專業人員等挑戰影響
# =========================
# 治挑戰時保持主導地位地緣政
# =========================
# 以及包含台灣公用事業成本上升在內的通貨膨脹等挑戰
# =========================
# 會遇到不少挑戰
# =========================
# 這對台積電建廠更是挑戰
# =========================
# 實現這些目標變得越來越具有挑戰性
# =========================
# 但在人力資源方面遇到挑戰
# =========================
# 至於台積電美國建廠遇到當地工會挑戰
# =========================
# 指數連四紅蓄勢挑戰季線未果
# =========================
# 台積電美國廠遭遇挑戰
# =========================
# 以及壓制超微英特爾等挑戰
# =========================
# 以FinFET技術控制電流變得極具挑戰性
# =========================
# 三星電子先前在奈米製程上面臨挑戰
# =========================
# 選舉行情挺 群益Q挑戰
# =========================
# 看好第四季指數高點可望挑戰
# =========================
# 台股今年第四季指數高點將衝破萬八上看挑戰
# =========================
# 盧東暉坦言確實存在挑戰
# =========================
# 芯的挑戰ondo的冷靜面對華為和中
# =========================
# 為了挑戰晶圓代工龍頭台積電地位
# =========================
# 但儘管面臨挑戰
# =========================
# 晶圓代工龍頭台積電今日舉行員工運動大會嚴峻
# =========================
# 以面對未來挑戰
# =========================
# 未來幾年的挑戰會跟過去一樣嚴峻
# =========================
# 可以面對未來的挑戰
# =========================
# 峻挑戰臨嚴
# =========================
# 針對法人提問英特爾不斷試圖挑戰台積電領導地位
# =========================
# 台積電不會害怕市占率挑戰
# =========================
# 者他也強調不會因此小看任何挑戰
# =========================
# NP已經表現出難以挑戰的性能
# =========================
# 挑戰永遠都在
# =========================
# 挑戰最大在於成本
# =========================
# 最大的挑戰仍是成本
# =========================
# 國泰永續高股息    股市 記者也真的很厲害持度頗具挑戰
# =========================
# 對汽車電子帶來嚴峻挑戰動駕駛將
# =========================
# 怎麼可能落下他的好兄弟呢向上漲是好朋友共同進退
# =========================
# 有望全年挑戰元
# =========================
# 雖然賣冰棒是一場與較大冰棒品牌競爭的大挑戰
# =========================
# 雖然賣冰棒是一場與較大冰棒品牌競爭的大挑戰
# =========================
# 按照我原本的預估應該已經再挑戰前高
# =========================
# 以上 就看你對台積電的信念有多強了
# =========================
# 先進半導體科技將有助於因應變革帶來的挑戰
# =========================
# 權值股帶動加權指數向上挑戰
# =========================
# 適逢全球面臨大缺工潮與高齡化挑戰
# =========================
# 治風險及全球永續課題
# =========================
# 列加速器目前唯一可挑戰NVIDIA的AI GPU霸主地位的超微AMD新一代Instinct MI系
# =========================
# 當大的挑戰也面臨相
# =========================
# 目標再往萬八挑戰
# =========================
# 訓練爾將藉由Gaudi 挑戰AI推論市場雖然英特爾也會涉入AI
# =========================
# 但在爭取主要客戶方面仍面臨挑戰
# =========================
# 難道華碩才是真AI 月也快達到了
# =========================
# 挑戰兆元水準有機會
# =========================
# 屆時台股將挑戰萬大關
# =========================
#  高手才有辦法緯創買 賣 波段 高手上升趨勢買 轉弱賣TF買攤平法解套質公司很多
# =========================
# 事後諸葛果然賣了就漲準備挑戰套牢的台積電自由了         股
# =========================
# EPS元不是那麼困難
# =========================
# 新台幣營收有機會挑戰兆元
# =========================
# 挑戰市值兆美元
# =========================
# 考量挑戰兆美元市值大有可為
# =========================
# 年總統大選底定彈百點挑戰回月線
# =========================
# 挑戰站回月線
# =========================
# 點位置挑戰站回
# =========================
# 月線指數向上反彈挑戰
# =========================
# 年對半導體產業是具備挑戰的一年
# =========================
# 靠台積電法說會 救了美股也救了全世界
# =========================
# 台股今天攻上點豪台北日電是很有信心
# =========================
# 美國想要複製台灣支持晶片製造的生態系統是一項巨大挑戰
# =========================
# 中國AI晶片產業面臨的更廣泛的挑戰
# =========================
# 的難度將再拉升台積電
# =========================
# 台灣大和遠傳誓言挑戰千萬用戶
# =========================
# Altman正尋求解決人工智能快速擴張領域面臨的一些重大挑戰
# =========================
# 年月日盤中所創下美元
# =========================
# 哪有沒有可能漲停到突破歷史前高明兩晚股價沒變化的情況下
# =========================
# 先恭喜手上有台積電的板友了是得小心留意才好能挑戰天價
# =========================
# 還有挑戰經濟
# =========================
# 雖然整體經濟還有挑戰
# =========================
# 真正挑戰才剛開始
# =========================
# 超微AMD預計今年下半年端出全新Zen 架構
# =========================
# 全年挑戰賺逾五個股本
# =========================
# 代工服務Systems Foundry個專為人工智慧AI時代設計的系統級晶圓
# =========================
# 將挑戰台積電地位
# =========================
# 這些巨頭回檔應該都是好的上車機會 對吧
# =========================
# 半導體技術面臨發展瓶頸與挑戰
# =========================
# 許挑戰兆美元市值關卡並非太難辦到
# =========================
# 谷歌今天美股開盤後有機會再挑戰超越亞馬遜與Googl
# =========================
# Qualcomm等多方強敵挑戰下
# =========================
# 不如挑戰彎道超車
# =========================
# 這次還要挑戰唱跳
# =========================
# 今天日挑戰重返點大關
# =========================
# 日挑戰重返點大關
# =========================
# 儘管會面臨挑戰
# =========================
# 看來三大法人只是略為看好台股挑戰一萬九千點大關
# =========================
# 台積電衝上元即將挑戰元
# =========================
# 接下來將挑戰點關卡
# =========================
# 去年Q獲利有機會挑戰全年高點
# =========================
# 非長期投資者突破前高
# =========================
# 協助他們因應電價上漲的挑戰
# =========================
# 台灣在這年來雖然面臨許多挑戰
# =========================
# 挑戰年歷史高價紀錄
# =========================
# 不喜歡嗎想講一句 留意風險跟部位
# =========================
# 常有機會戰歷史新高非
# =========================
# 股市這回輕輕鬆鬆挑戰兩萬點
# =========================

# %% [markdown]
# #### 重新計算情緒

# %% [markdown]
# 控制、問題、擔心、錯過、隨便、強烈、負擔、口吃、挑剔、壓力、邪惡、禁止、挑戰、謝謝、智能、智慧

# %%
# 設定要移除的字詞列表
words_to_remove = ['問題', '控制', '擔心', '錯過', '隨便', '強烈', '負擔', '口吃', '挑剔', '壓力', '邪惡', '禁止',
                   '挑戰', '謝謝', '智能', '智慧']
# 使用 ~ 運算子和 isin() 方法過濾掉包含在 words_to_remove 列表中的行
liwc_dict_revise = liwc_dict[~liwc_dict['word'].isin(words_to_remove)]
# 使用更新後的情緒字典 merge
ptt_liwc_df_revise = pd.merge(noStop_df[["artUrl", "artDate", "artTitle", "artContent", "word"]], liwc_dict_revise,
                              how="left")
ptt_liwc_df_revise.head()
# Out:
#                                               artUrl     artDate  \
# 0  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 1  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 2  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 3  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 4  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
#
#                  artTitle                                         artContent  \
# 0  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 2  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 3  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 4  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
#
#   word sentiments
# 0   標的        NaN
# 1   富時        NaN
# 2  不動產        NaN
# 3   分析        NaN
# 4   正文        NaN

# %%
word_count = ptt_liwc_df_revise.groupby(["word", "sentiments"]).size().reset_index()
word_count = word_count.rename(columns={0: "size"})
word_count = word_count.sort_values(["size"], ascending=False)
word_of_pos = word_count.loc[(word_count["sentiments"] == "positive")]
word_of_neg = word_count.loc[(word_count["sentiments"] == "negative")]
pos = word_of_pos.head(15).sort_values(["size"], ascending=True)
neg = word_of_neg.head(15).sort_values(["size"], ascending=True)

fig, ax = plt.subplots(1, 2)

ax[0].barh(pos["word"], pos["size"], color=colors[0])
ax[0].set_xlabel("count")
ax[0].set_yticklabels(pos["word"])
ax[0].set_title("正向情緒總數")

ax[1].barh(neg["word"], neg["size"], color=colors[1])
ax[1].set_xlabel("count")
ax[1].set_yticklabels(neg["word"])
ax[1].set_title("負向情緒總數")
# Out:
# C:\Users\eddie\AppData\Local\Temp\ipykernel_13276\2371119238.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_yticklabels(pos["word"])
# C:\Users\eddie\AppData\Local\Temp\ipykernel_13276\2371119238.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_yticklabels(neg["word"])
# Text(0.5, 1.0, '負向情緒總數')

# %% [markdown]
# 重新繪製情緒分數趨勢圖

# %%
sentiment_count_revise = pd.DataFrame(
    ptt_liwc_df_revise.groupby(["artDate", "sentiments"]).size()
).reset_index()

mask = (sentiment_count_revise['sentiments'] == "positive") | (sentiment_count_revise['sentiments'] == "negative") 
sentiment_count_revise = sentiment_count_revise.loc[mask]

sentiment_count_revise = sentiment_count_revise.rename(columns={0: "size"})
sentiment_count_revise = sentiment_count_revise.sort_values(["artDate"])

ptt_sentiment_value_revise = (
    sentiment_count_revise.pivot_table(
        index="artDate", columns="sentiments", values="size", fill_value=0
    )
    .reset_index()
    .rename_axis(None, axis=1)
)

# sentiment 計算方式: positive - negative
ptt_sentiment_value_revise["sentiment_value"] = (
    ptt_sentiment_value_revise["positive"]
    - ptt_sentiment_value_revise["negative"]
)

# 繪製情緒分數趨勢圖
fig, ax = plt.subplots()

rolling_days = 14
ax.plot(ptt_sentiment_value_revise["artDate"], ptt_sentiment_value_revise["sentiment_value"].rolling(rolling_days).mean())
ax.set_xlabel("artDate")
ax.set_ylabel("sentiment value")
fig.autofmt_xdate()
plt.title("正負情緒分數趨勢折線圖")
# Out:
# Text(0.5, 1.0, '正負情緒分數趨勢折線圖')

# %% [markdown]
# ### 3.8 文字雲
# 如果文字雲中的字詞大小越大，代表出現頻率越高

# %% [markdown]
# #### 2023-10-15 ~2023-11-01 文字雲
# 2023-10-15 ~2023-11-01 在情緒分數趨勢圖上顯示比較低的分數，我們用文字雲來看一下這段時間出現了什麼關鍵字

# %% [markdown]
# 將前面計算出的文章情緒類別合併，以利我們過濾出負面文章資料

# %%
ptt_liwc_df_revise = pd.merge(ptt_liwc_df_revise, ptt_sentiment_value_by_article[['artUrl', 'sentiment_class']], how="left")
ptt_liwc_df_revise.head()
# Out:
#                                               artUrl     artDate  \
# 0  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 1  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 2  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 3  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
# 4  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  2023-03-20
#
#                  artTitle                                         artContent  \
# 0  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 2  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 3  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 4  [標的]00712富時不動產天天大溢價要賣？  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
#
#   word sentiments sentiment_class
# 0   標的        NaN              負向
# 1   富時        NaN              負向
# 2  不動產        NaN              負向
# 3   分析        NaN              負向
# 4   正文        NaN              負向

# %%
sent_df = pd.merge(sent_df, ptt_sentiment_value_by_article[['artUrl', 'sentiment_class']], how="left")
sent_df.head()
# Out:
#                                               artUrl                artTitle  \
# 0  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  [標的]00712富時不動產天天大溢價要賣？
# 1  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  [標的]00712富時不動產天天大溢價要賣？
# 2  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  [標的]00712富時不動產天天大溢價要賣？
# 3  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  [標的]00712富時不動產天天大溢價要賣？
# 4  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...  [標的]00712富時不動產天天大溢價要賣？
#
#       artDate                                         artContent  \
# 0  2023-03-20  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1  2023-03-20  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 2  2023-03-20  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 3  2023-03-20  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 4  2023-03-20  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
#
#                                             sentence sentiment_class
# 0   標的  富時不動產\r例 TW 台積電\r 分類討論\r\r 分析正文\r\r這隻已經超過...              負向
# 1                                          股價卻沒有急速下跌              負向
# 2                                        是每天凌遲你那種小小跌              負向
# 3                                             明\r天除息              負向
# 4                                        整年殖利率可能有趴以上              負向

# %%
date = "2023-10-15"
end_date = "2023-11-01"
mask = (ptt_liwc_df_revise['artDate'] >= pd.Timestamp(date).date()) & (
    ptt_liwc_df_revise['artDate'] <= pd.Timestamp(end_date).date()) & (
    ptt_liwc_df_revise['sentiment_class'] == "負向")

ptt_df_wc = ptt_liwc_df_revise.loc[mask]
ptt_df_wc
# Out:
#                                                    artUrl     artDate  \
# 200830  https://www.ptt.cc/bbs/Stock/M.1697371888.A.94...  2023-10-15
# 200831  https://www.ptt.cc/bbs/Stock/M.1697371888.A.94...  2023-10-15
# 200832  https://www.ptt.cc/bbs/Stock/M.1697371888.A.94...  2023-10-15
# 200833  https://www.ptt.cc/bbs/Stock/M.1697371888.A.94...  2023-10-15
# 200834  https://www.ptt.cc/bbs/Stock/M.1697371888.A.94...  2023-10-15
# ...                                                   ...         ...
# 219146  https://www.ptt.cc/bbs/Stock/M.1698801603.A.A8...  2023-11-01
# 219147  https://www.ptt.cc/bbs/Stock/M.1698801603.A.A8...  2023-11-01
# 219148  https://www.ptt.cc/bbs/Stock/M.1698801603.A.A8...  2023-11-01
# 219149  https://www.ptt.cc/bbs/Stock/M.1698801603.A.A8...  2023-11-01
# 219150  https://www.ptt.cc/bbs/Stock/M.1698801603.A.A8...  2023-11-01
#
#                         artTitle  \
# 200830      [新聞]詐騙廣告平台24小時不下架立即罰
# 200831      [新聞]詐騙廣告平台24小時不下架立即罰
# 200832      [新聞]詐騙廣告平台24小時不下架立即罰
# 200833      [新聞]詐騙廣告平台24小時不下架立即罰
# 200834      [新聞]詐騙廣告平台24小時不下架立即罰
# ...                          ...
# 219146  [新聞]愈跌愈護！八大官股券商認真買！13個交易
# 219147  [新聞]愈跌愈護！八大官股券商認真買！13個交易
# 219148  [新聞]愈跌愈護！八大官股券商認真買！13個交易
# 219149  [新聞]愈跌愈護！八大官股券商認真買！13個交易
# 219150  [新聞]愈跌愈護！八大官股券商認真買！13個交易
#
#                                                artContent word sentiments  \
# 200830  原文標題：\r\n\r\n詐騙廣告 平台24小時不下架立即罰\r\n\r\n原文連結：\r\...   詐騙     affect
# 200831  原文標題：\r\n\r\n詐騙廣告 平台24小時不下架立即罰\r\n\r\n原文連結：\r\...   詐騙   negative
# 200832  原文標題：\r\n\r\n詐騙廣告 平台24小時不下架立即罰\r\n\r\n原文連結：\r\...   詐騙      anger
# 200833  原文標題：\r\n\r\n詐騙廣告 平台24小時不下架立即罰\r\n\r\n原文連結：\r\...   廣告        NaN
# 200834  原文標題：\r\n\r\n詐騙廣告 平台24小時不下架立即罰\r\n\r\n原文連結：\r\...   平台        NaN
# ...                                                   ...  ...        ...
# 219146  原文標題：愈跌愈護！八大官股券商認真買！　13個交易日砸近270億愛台股\r\nhttps:...   股利        NaN
# 219147  原文標題：愈跌愈護！八大官股券商認真買！　13個交易日砸近270億愛台股\r\nhttps:...  零用錢        NaN
# 219148  原文標題：愈跌愈護！八大官股券商認真買！　13個交易日砸近270億愛台股\r\nhttps:...   乖乖        NaN
# 219149  原文標題：愈跌愈護！八大官股券商認真買！　13個交易日砸近270億愛台股\r\nhttps:...   爆發     affect
# 219150  原文標題：愈跌愈護！八大官股券商認真買！　13個交易日砸近270億愛台股\r\nhttps:...   爆發   negative
#
#        sentiment_class
# 200830              負向
# 200831              負向
# 200832              負向
# 200833              負向
# 200834              負向
# ...                ...
# 219146              負向
# 219147              負向
# 219148              負向
# 219149              負向
# 219150              負向
#
# [5105 rows x 7 columns]

# %%
date = "2023-10-15"
end_date = "2023-11-01"
mask = (ptt_liwc_df_revise['artDate'] >= pd.Timestamp(date).date()) & (
    ptt_liwc_df_revise['artDate'] <= pd.Timestamp(end_date).date()) & (
    ptt_liwc_df_revise['sentiment_class'] == "負向")

ptt_df_wc = ptt_liwc_df_revise.loc[mask, ["artDate", "word"]]


word_count_count = pd.DataFrame(
    ptt_df_wc.groupby(["word"]).size()
).reset_index().rename(columns={0: "size"})
word_count_count = word_count_count.sort_values(by='size', ascending=False)
word_count_count
# Out:
#       word  size
# 1684    美債    44
# 2       AI    34
# 1801    衝突    33
# 1925    賣超    32
# 19     ETF    30
# ...    ...   ...
# 1323    此事     1
# 1322    此一     1
# 503   十二小時     1
# 504   十二萬元     1
# 2284    龍頭     1
#
# [2285 rows x 2 columns]

# %%
# wordcloud 的 input 是 dictionary
wc_dict = dict(zip(word_count_count['word'], word_count_count['size']))
cloud = WordCloud(max_words=200, background_color="white", font_path=font_path)
cloud.generate_from_frequencies(wc_dict)
# 繪圖
plt.figure(figsize=(8, 4), dpi=150)
plt.imshow(cloud, interpolation="bilinear")
plt.axis("off")
# plt.show()
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# 關鍵字出現了「美債」、「AI」、「賣超」、「衝突」、「下跌」的關鍵字，可能是在說明美債導致台積電下跌

# %%
date = "2023-10-15"
end_date = "2023-11-01"
mask = (ptt_liwc_df_revise['artDate'] >= pd.Timestamp(date).date()) & (
    ptt_liwc_df_revise['artDate'] <= pd.Timestamp(end_date).date()) & ( # 時間區間
    ptt_liwc_df_revise['sentiment_class'] == "負向")  & ( # 負面文章
    ptt_liwc_df_revise['artContent'].str.contains('美債')) & ( # 內文包含美債
    ptt_liwc_df_revise["sentiments"] == "negative") # 負面情緒字

ptt_df_wc = ptt_liwc_df_revise.loc[mask, ["artDate", "word"]]
wc = ptt_df_wc.groupby(["word"]).size().to_dict()

# wordcloud 的 input 是 dictionary
cloud = WordCloud(max_words=200, background_color="white", font_path=font_path, colormap="GnBu")
cloud.generate_from_frequencies(wc)
# 繪圖
plt.figure(figsize=(8, 4), dpi=150)
plt.imshow(
    cloud, 
    interpolation="bilinear"
)
plt.axis("off")
# plt.show()
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# 利用「擔憂」去查看原文內容

# %%
date = "2023-10-15"
end_date = "2023-11-01"
mask = (sent_df['artDate'] >= pd.Timestamp(date).date()) & (
    sent_df['artDate'] <= pd.Timestamp(end_date).date()) & (
    sent_df['sentiment_class'] == "負向") & (
    sent_df['artContent'].str.contains('美債')) & (
    sent_df['sentence'].str.contains('擔憂')) # 包含「擔憂」的句子

df_ = sent_df.loc[mask, ["artDate", "artContent", "sentence"]]
index_list = df_.index.tolist()


# 取得前後各5筆的索引 => 目的為查看包含該詞彙句子的上下文
surrounding_indices = []
for index in index_list:
    surrounding_indices.extend(range(index - 5, index + 6))

# 去除重複的索引，並確保不超出範圍
surrounding_indices = list(set(filter(lambda x: x >= 0 and x < len(sent_df), surrounding_indices)))

# 依據索引取得相應的資料
result_df = sent_df.iloc[surrounding_indices].sort_index()
result_df
# Out:
#                                                   artUrl  \
# 44917  https://www.ptt.cc/bbs/Stock/M.1697544902.A.71...
# 44918  https://www.ptt.cc/bbs/Stock/M.1697545308.A.90...
# 44919  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44920  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44921  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44922  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44923  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44924  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44925  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44926  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
# 44927  https://www.ptt.cc/bbs/Stock/M.1697552603.A.1D...
#
#                       artTitle     artDate  \
# 44917    [情報]1017上市櫃外資投信買超金額排行  2023-10-17
# 44918      [情報]1017上市櫃外資投信同買排行  2023-10-17
# 44919  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44920  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44921  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44922  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44923  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44924  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44925  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44926  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
# 44927  [新聞]美擴大限制輝達晶片銷陸輝達早盤急挫6%  2023-10-17
#
#                                               artContent  \
# 44917  外資\r\n\r\n排行  股票名稱     百萬   收盤價   漲跌\r\n\r\n1 ...
# 44918  排行   股票名稱    成交    漲跌   投信買   外資買\r\n\r\n1    ...
# 44919  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44920  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44921  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44922  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44923  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44924  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44925  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44926  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
# 44927  原文標題：美擴大限制輝達晶片銷陸 輝達早盤急挫6%\r\n\r\n原文連結：\r\nhttp...
#
#                                                 sentence sentiment_class
# 44917  外資\r\r排行  股票名稱     百萬   收盤價   漲跌\r\r     台積電  ...              正向
# 44918  排行   股票名稱    成交    漲跌   投信買   外資買\r\r      聯電 ...              正向
# 44919  原文標題美擴大限制輝達晶片銷陸 輝達早盤急挫\r\r原文連結\r\r發布時間 \r\r記者署...              負向
# 44920                                            美債殖利率走升              負向
# 44921                             \r美國最新公布的零售銷售數據遠高於\r預期              負向
# 44922                          引發投資人擔憂聯準會Fed可能將利率維持在高檔更久              負向
# 44923                                            並可能再度升息              負向
# 44924                                             \r同\r時              負向
# 44925                                    \r道瓊工業指數早盤跌近百點或              負向
# 44926                                   標普指數和那斯達克綜合指數各跌和              負向
# 44927                                        \r費城半導體指數下挫              負向

# %% [markdown]
# 文章中提到了這間排餐的雞腿排的皮處理得不夠酥脆
